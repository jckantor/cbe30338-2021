# %% [markdown]
# # [cbe30338-2021](https://jckantor.github.io/cbe30338-2021)
#
# ## Index of Python Libraries used in this Repository
#
# ### cvxpy
# * [4.7.4 CVXPY](https://jckantor.github.io/cbe30338-2021/04.07-Observer-Synthesis-LMI.html#4.7.4-CVXPY)
# * [4.7.5 $\cal{H}_2$ Optimal State Estimation](https://jckantor.github.io/cbe30338-2021/04.07-Observer-Synthesis-LMI.html#4.7.5-$\cal{H}_2$-Optimal-State-Estimation)
# * [4.7.5 $\cal{H}_2$ Optimal State Estimation](https://jckantor.github.io/cbe30338-2021/04.07-Observer-Synthesis-LMI.html#4.7.5-$\cal{H}_2$-Optimal-State-Estimation)
# * [4.7.6 $\cal{H}_{\infty}$ Optimal State Estimation](https://jckantor.github.io/cbe30338-2021/04.07-Observer-Synthesis-LMI.html#4.7.6-$\cal{H}_{\infty}$-Optimal-State-Estimation)
# * [4.8.2 State Space Model](https://jckantor.github.io/cbe30338-2021/04.08-State-Estimation-Envrironmental-Application.html#4.8.2-State-Space-Model)
# * [5.1.4 Solution using CVXPY](https://jckantor.github.io/cbe30338-2021/05.01-Linear-Production-Model.html#5.1.4-Solution-using-CVXPY)
# * [5.1.5 Solution using scipy.optimize.linprog](https://jckantor.github.io/cbe30338-2021/05.01-Linear-Production-Model.html#5.1.5-Solution-using-scipy.optimize.linprog)
# * [5.2.2 Solving optimization problems with CVXPY](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.2-Solving-optimization-problems-with-CVXPY)
# * [5.2.3.1 Consolidating](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.1-Consolidating)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [6.1.3.1 Imports](https://jckantor.github.io/cbe30338-2021/06.01-Static-Operability.html#6.1.3.1-Imports)
# * [6.2.1.2 Parameter Values](https://jckantor.github.io/cbe30338-2021/06.02-Simulation-and-Open-Loop-Optimal-Control.html#6.2.1.2-Parameter-Values)
# * [6.3.1 Feedforward Optimal Control](https://jckantor.github.io/cbe30338-2021/06.03-Predictive-Control.html#6.3.1-Feedforward-Optimal-Control)
# * [6.4.1 Model](https://jckantor.github.io/cbe30338-2021/06.04-Implementing-Predictive-Control.html#6.4.1-Model)
#
# ### matplotlib
# * [1.4.6 The TCLab `Plotter`](https://jckantor.github.io/cbe30338-2021/01.04-TCLab-Python-Package.html#1.4.6-The-TCLab-`Plotter`)
# * [2.1.3.1.2 Step 1. Import libraries](https://jckantor.github.io/cbe30338-2021/02.01-One-Compartment-Pharmacokinetics.html#2.1.3.1.2-Step-1.-Import-libraries)
# * [2.2.2 Steady-State Gain](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.2-Steady-State-Gain)
# * [2.2.3.1 Response to an Initial Condition](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.1-Response-to-an-Initial-Condition)
# * [2.2.3.2 Time constant](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.2-Time-constant)
# * [2.2.3.3 Half-life](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.3-Half-life)
# * [2.2.3.3 Half-life](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.3-Half-life)
# * [2.2.3.4 Step Inputs](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.4-Step-Inputs)
# * [2.2.3.4 Step Inputs](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.4-Step-Inputs)
# * [2.2.4 Response to a step input](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.4-Response-to-a-step-input)
# * [2.3.2.9 Plotting the Analytical Solution](https://jckantor.github.io/cbe30338-2021/02.03-First-Order-Model-for-a-Single-Heater.html#2.3.2.9-Plotting-the-Analytical-Solution)
# * [2.3.3 Matching the Model to Experimental Data](https://jckantor.github.io/cbe30338-2021/02.03-First-Order-Model-for-a-Single-Heater.html#2.3.3-Matching-the-Model-to-Experimental-Data)
# * [2.4.1.1 Read data into a Pandas DataFrame](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.1.1-Read-data-into-a-Pandas-DataFrame)
# * [2.4.4 First order Energy balance model](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.4-First-order-Energy-balance-model)
# * [2.4.6.1 Dynamics of the Heater/Sensor System](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.6.1-Dynamics-of-the-Heater/Sensor-System)
# * [2.4.7.2 Standard form](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.7.2-Standard-form)
# * [3.2.1 Setpoint profiles](https://jckantor.github.io/cbe30338-2021/03.02-Setpoints.html#3.2.1-Setpoint-profiles)
# * [3.2.2.1 Specifying piecewise linear setpoint profiles](https://jckantor.github.io/cbe30338-2021/03.02-Setpoints.html#3.2.2.1-Specifying-piecewise-linear-setpoint-profiles)
# * [3.2.3.2 Representing PCR protocols in Python](https://jckantor.github.io/cbe30338-2021/03.02-Setpoints.html#3.2.3.2-Representing-PCR-protocols-in-Python)
# * [3.9 Lab Assignment 4: Solution](https://jckantor.github.io/cbe30338-2021/03.09-Lab-Assignment-Solution.html#3.9-Lab-Assignment-4:-Solution)
# * [4.1.2.1.2 Accessing Data using `.columns` and `.fields`](https://jckantor.github.io/cbe30338-2021/04.01-Process-Historians.html#4.1.2.1.2-Accessing-Data-using-`.columns`-and-`.fields`)
# * [4.2.1 Output Feedback Control ](https://jckantor.github.io/cbe30338-2021/04.02-State-Estimation.html#4.2.1-Output-Feedback-Control)
# * [4.4.4 Eigenvalues](https://jckantor.github.io/cbe30338-2021/04.04-State-Estimation-Copy1.html#4.4.4-Eigenvalues)
# * [4.6 Lab Assignment 6: Anomaly Detection](https://jckantor.github.io/cbe30338-2021/04.06-Lab-Assignment-Anomaly-Detection.html#4.6-Lab-Assignment-6:-Anomaly-Detection)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.6.2 Denatured Alcohol](https://jckantor.github.io/cbe30338-2021/05.06-Design-of-a-Cold-Weather-Fuel.html#5.6.2-Denatured-Alcohol)
# * [6.2.1.2 Parameter Values](https://jckantor.github.io/cbe30338-2021/06.02-Simulation-and-Open-Loop-Optimal-Control.html#6.2.1.2-Parameter-Values)
# * [6.3.1 Feedforward Optimal Control](https://jckantor.github.io/cbe30338-2021/06.03-Predictive-Control.html#6.3.1-Feedforward-Optimal-Control)
# * [6.4.1 Model](https://jckantor.github.io/cbe30338-2021/06.04-Implementing-Predictive-Control.html#6.4.1-Model)
# * [7.1.3 Ready to Roomba](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.3-Ready-to-Roomba)
# * [7.1.4 Chemotaxis](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.4-Chemotaxis)
# * [A.24.3.1 Step 1. Create the background frame.](https://jckantor.github.io/cbe30338-2021/A.24-Animation-in-Jupyter-Notebooks.html#A.24.3.1-Step-1.-Create-the-background-frame.)
# * [A.24.4 Example: Phase Plane Animation for an Exothermic Stirred-Tank Reactor](https://jckantor.github.io/cbe30338-2021/A.24-Animation-in-Jupyter-Notebooks.html#A.24.4-Example:-Phase-Plane-Animation-for-an-Exothermic-Stirred-Tank-Reactor)
#
# ### numpy
# * [2.1.3.1.2 Step 1. Import libraries](https://jckantor.github.io/cbe30338-2021/02.01-One-Compartment-Pharmacokinetics.html#2.1.3.1.2-Step-1.-Import-libraries)
# * [2.2.2 Steady-State Gain](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.2-Steady-State-Gain)
# * [2.2.3.1 Response to an Initial Condition](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.1-Response-to-an-Initial-Condition)
# * [2.2.3.2 Time constant](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.2-Time-constant)
# * [2.2.3.3 Half-life](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.3-Half-life)
# * [2.2.3.3 Half-life](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.3-Half-life)
# * [2.2.3.4 Step Inputs](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.4-Step-Inputs)
# * [2.2.3.4 Step Inputs](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.3.4-Step-Inputs)
# * [2.2.4 Response to a step input](https://jckantor.github.io/cbe30338-2021/02.02-Properties-of-Scalar-First-Order-Linear-Systems.html#2.2.4-Response-to-a-step-input)
# * [2.3.2.9 Plotting the Analytical Solution](https://jckantor.github.io/cbe30338-2021/02.03-First-Order-Model-for-a-Single-Heater.html#2.3.2.9-Plotting-the-Analytical-Solution)
# * [2.4.1.1 Read data into a Pandas DataFrame](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.1.1-Read-data-into-a-Pandas-DataFrame)
# * [2.4.4 First order Energy balance model](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.4-First-order-Energy-balance-model)
# * [2.4.6.1 Dynamics of the Heater/Sensor System](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.6.1-Dynamics-of-the-Heater/Sensor-System)
# * [2.4.7.2 Standard form](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.7.2-Standard-form)
# * [3.2.1 Setpoint profiles](https://jckantor.github.io/cbe30338-2021/03.02-Setpoints.html#3.2.1-Setpoint-profiles)
# * [3.2.2.1 Specifying piecewise linear setpoint profiles](https://jckantor.github.io/cbe30338-2021/03.02-Setpoints.html#3.2.2.1-Specifying-piecewise-linear-setpoint-profiles)
# * [3.2.3.2 Representing PCR protocols in Python](https://jckantor.github.io/cbe30338-2021/03.02-Setpoints.html#3.2.3.2-Representing-PCR-protocols-in-Python)
# * [3.9 Lab Assignment 4: Solution](https://jckantor.github.io/cbe30338-2021/03.09-Lab-Assignment-Solution.html#3.9-Lab-Assignment-4:-Solution)
# * [4.2.1 Output Feedback Control ](https://jckantor.github.io/cbe30338-2021/04.02-State-Estimation.html#4.2.1-Output-Feedback-Control)
# * [4.2.5 Model Predictions](https://jckantor.github.io/cbe30338-2021/04.02-State-Estimation.html#4.2.5-Model-Predictions)
# * [4.2.7.1 Fun with Eigenvalues](https://jckantor.github.io/cbe30338-2021/04.02-State-Estimation.html#4.2.7.1-Fun-with-Eigenvalues)
# * [4.4.1 State-Space Model](https://jckantor.github.io/cbe30338-2021/04.04-State-Estimation-Copy1.html#4.4.1-State-Space-Model)
# * [4.6 Lab Assignment 6: Anomaly Detection](https://jckantor.github.io/cbe30338-2021/04.06-Lab-Assignment-Anomaly-Detection.html#4.6-Lab-Assignment-6:-Anomaly-Detection)
# * [4.7.4 CVXPY](https://jckantor.github.io/cbe30338-2021/04.07-Observer-Synthesis-LMI.html#4.7.4-CVXPY)
# * [4.7.5 $\cal{H}_2$ Optimal State Estimation](https://jckantor.github.io/cbe30338-2021/04.07-Observer-Synthesis-LMI.html#4.7.5-$\cal{H}_2$-Optimal-State-Estimation)
# * [4.7.5 $\cal{H}_2$ Optimal State Estimation](https://jckantor.github.io/cbe30338-2021/04.07-Observer-Synthesis-LMI.html#4.7.5-$\cal{H}_2$-Optimal-State-Estimation)
# * [4.7.6 $\cal{H}_{\infty}$ Optimal State Estimation](https://jckantor.github.io/cbe30338-2021/04.07-Observer-Synthesis-LMI.html#4.7.6-$\cal{H}_{\infty}$-Optimal-State-Estimation)
# * [4.8.2 State Space Model](https://jckantor.github.io/cbe30338-2021/04.08-State-Estimation-Envrironmental-Application.html#4.8.2-State-Space-Model)
# * [4.8.2 State Space Model](https://jckantor.github.io/cbe30338-2021/04.08-State-Estimation-Envrironmental-Application.html#4.8.2-State-Space-Model)
# * [5.1.4 Solution using CVXPY](https://jckantor.github.io/cbe30338-2021/05.01-Linear-Production-Model.html#5.1.4-Solution-using-CVXPY)
# * [5.1.5 Solution using scipy.optimize.linprog](https://jckantor.github.io/cbe30338-2021/05.01-Linear-Production-Model.html#5.1.5-Solution-using-scipy.optimize.linprog)
# * [5.2.2 Solving optimization problems with CVXPY](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.2-Solving-optimization-problems-with-CVXPY)
# * [5.2.3.1 Consolidating](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.1-Consolidating)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.2.3.2 Optimal blend as a function of product specification](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.2-Optimal-blend-as-a-function-of-product-specification)
# * [5.6.2 Denatured Alcohol](https://jckantor.github.io/cbe30338-2021/05.06-Design-of-a-Cold-Weather-Fuel.html#5.6.2-Denatured-Alcohol)
# * [5.98.5.1 Data in Matrix/Vector Format](https://jckantor.github.io/cbe30338-2021/05.98-Linear-Production-Model-in-Pyomo.html#5.98.5.1-Data-in-Matrix/Vector-Format)
# * [5.99.3 Example 19.3: Linear Programming Refinery](https://jckantor.github.io/cbe30338-2021/05.99-Pyomo-Examples.html#5.99.3-Example-19.3:-Linear-Programming-Refinery)
# * [6.1.3.1 Imports](https://jckantor.github.io/cbe30338-2021/06.01-Static-Operability.html#6.1.3.1-Imports)
# * [6.2.1.2 Parameter Values](https://jckantor.github.io/cbe30338-2021/06.02-Simulation-and-Open-Loop-Optimal-Control.html#6.2.1.2-Parameter-Values)
# * [6.3.1 Feedforward Optimal Control](https://jckantor.github.io/cbe30338-2021/06.03-Predictive-Control.html#6.3.1-Feedforward-Optimal-Control)
# * [6.3.3 TCLab Event Loop](https://jckantor.github.io/cbe30338-2021/06.03-Predictive-Control.html#6.3.3-TCLab-Event-Loop)
# * [6.4.1 Model](https://jckantor.github.io/cbe30338-2021/06.04-Implementing-Predictive-Control.html#6.4.1-Model)
# * [7.1.4 Chemotaxis](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.4-Chemotaxis)
# * [A.24.3.1 Step 1. Create the background frame.](https://jckantor.github.io/cbe30338-2021/A.24-Animation-in-Jupyter-Notebooks.html#A.24.3.1-Step-1.-Create-the-background-frame.)
# * [A.24.4 Example: Phase Plane Animation for an Exothermic Stirred-Tank Reactor](https://jckantor.github.io/cbe30338-2021/A.24-Animation-in-Jupyter-Notebooks.html#A.24.4-Example:-Phase-Plane-Animation-for-an-Exothermic-Stirred-Tank-Reactor)
#
# ### pandas
# * [1.4.5 The TCLab `Historian`](https://jckantor.github.io/cbe30338-2021/01.04-TCLab-Python-Package.html#1.4.5-The-TCLab-`Historian`)
# * [2.3.2.5 Estimating $\alpha$](https://jckantor.github.io/cbe30338-2021/02.03-First-Order-Model-for-a-Single-Heater.html#2.3.2.5-Estimating-$\alpha$)
# * [2.3.3 Matching the Model to Experimental Data](https://jckantor.github.io/cbe30338-2021/02.03-First-Order-Model-for-a-Single-Heater.html#2.3.3-Matching-the-Model-to-Experimental-Data)
# * [2.4.1.1 Read data into a Pandas DataFrame](https://jckantor.github.io/cbe30338-2021/02.04-Model-Identification.html#2.4.1.1-Read-data-into-a-Pandas-DataFrame)
# * [3.9 Lab Assignment 4: Solution](https://jckantor.github.io/cbe30338-2021/03.09-Lab-Assignment-Solution.html#3.9-Lab-Assignment-4:-Solution)
# * [4.1.2.1.4 Accessing Data using `pandas`](https://jckantor.github.io/cbe30338-2021/04.01-Process-Historians.html#4.1.2.1.4-Accessing-Data-using-`pandas`)
# * [4.2.1 Output Feedback Control ](https://jckantor.github.io/cbe30338-2021/04.02-State-Estimation.html#4.2.1-Output-Feedback-Control)
# * [5.2.3.1 Consolidating](https://jckantor.github.io/cbe30338-2021/05.02-Linear-Blending-Problem.html#5.2.3.1-Consolidating)
# * [5.4 Gasoline Blending](https://jckantor.github.io/cbe30338-2021/05.04-Gasoline-Blending.html#5.4-Gasoline-Blending)
# * [5.6.5 Display Composition](https://jckantor.github.io/cbe30338-2021/05.06-Design-of-a-Cold-Weather-Fuel.html#5.6.5-Display-Composition)
# * [5.99.3 Example 19.3: Linear Programming Refinery](https://jckantor.github.io/cbe30338-2021/05.99-Pyomo-Examples.html#5.99.3-Example-19.3:-Linear-Programming-Refinery)
#
# ### pyomo
# * [5.4 Gasoline Blending](https://jckantor.github.io/cbe30338-2021/05.04-Gasoline-Blending.html#5.4-Gasoline-Blending)
# * [5.4.3 Blending Model](https://jckantor.github.io/cbe30338-2021/05.04-Gasoline-Blending.html#5.4.3-Blending-Model)
# * [5.6.4 Optimization Model](https://jckantor.github.io/cbe30338-2021/05.06-Design-of-a-Cold-Weather-Fuel.html#5.6.4-Optimization-Model)
# * [5.99.1 Pyomo Model](https://jckantor.github.io/cbe30338-2021/05.99-Pyomo-Examples.html#5.99.1-Pyomo-Model)
#
# ### seaborn
# * [A.24.3.1 Step 1. Create the background frame.](https://jckantor.github.io/cbe30338-2021/A.24-Animation-in-Jupyter-Notebooks.html#A.24.3.1-Step-1.-Create-the-background-frame.)
# * [A.24.4 Example: Phase Plane Animation for an Exothermic Stirred-Tank Reactor](https://jckantor.github.io/cbe30338-2021/A.24-Animation-in-Jupyter-Notebooks.html#A.24.4-Example:-Phase-Plane-Animation-for-an-Exothermic-Stirred-Tank-Reactor)
#
# ### simpy
# * [7.1.1.1 Creating a simulation environment](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.1.1-Creating-a-simulation-environment)
# * [7.1.1.2 Creating simulation processes](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.1.2-Creating-simulation-processes)
# * [7.1.1.2 Creating simulation processes](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.1.2-Creating-simulation-processes)
# * [7.1.2 Events](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.2-Events)
# * [7.1.3 Ready to Roomba](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.3-Ready-to-Roomba)
# * [7.1.3 Ready to Roomba](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.3-Ready-to-Roomba)
# * [7.1.4 Chemotaxis](https://jckantor.github.io/cbe30338-2021/07.01-Introduction-to-Simpy.html#7.1.4-Chemotaxis)
#
# ### tclab
# * [1.4.8 Running Diagnostics](https://jckantor.github.io/cbe30338-2021/01.04-TCLab-Python-Package.html#1.4.8-Running-Diagnostics)
#
# ### time
# * [1.4.3.2 Setting heater power with `.Q1()` and `.Q2()`](https://jckantor.github.io/cbe30338-2021/01.04-TCLab-Python-Package.html#1.4.3.2-Setting-heater-power-with-`.Q1()`-and-`.Q2()`)
# * [1.4.4 Synchronizing with Real Time using `clock`](https://jckantor.github.io/cbe30338-2021/01.04-TCLab-Python-Package.html#1.4.4-Synchronizing-with-Real-Time-using-`clock`)
